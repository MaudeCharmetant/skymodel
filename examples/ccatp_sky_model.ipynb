# %%
# %matplotlib inline
import pysm as pysm
import ccatp_sky_model as sky
from astropy.io import fits
import healpy as hp
import numpy as n
import matplotlib.cm as cm
from tqdm import tqdm

# %%
CAMB = '/vol/aibn1118/data1/mcharmetant/Data/Simons_Obs_2010/'+'CMB_8192.dat'

# %%
test = sky.ccatp_sky_model(freq=143e9, sensitivity=None, components='all', red_noise=False,
                           cl_file=None, lensed=False, out_file='second_test.fits', nside_out=4096,
                           lmax=None, beam_FWHM=None, template='SO', unit='cmb')
# Out:
# Computing Galactic foregounds...
# Sigma is 4.246609 arcmin (0.001235 rad)
# -> fwhm is 10.000000 arcmin
# Sigma is 0.000000 arcmin (0.000000 rad)
# -> fwhm is 0.000000 arcmin
# Galactic foregounds complete.
# Computing CIB...
# NSIDE = 4096
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# NSIDE = 4096
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# NSIDE = 4096
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# CIB complete.
# Computing radio PS...
# NSIDE = 4096
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# NSIDE = 4096
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# NSIDE = 4096
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# NSIDE = 4096
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# NSIDE = 4096
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# NSIDE = 4096
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# NSIDE = 4096
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# NSIDE = 4096
# ORDERING = RING in fits file
# ...

# %%
import matplotlib.pyplot as plt

# %%
file = hp.read_map('second_test.fits') 
hp.mollview(map=file*1e6, norm = "hist", cmap = "RdYlBu_r", coord = ("G"), xsize = 5000, title = "", cbar = False, unit='$\mu K_{CMB}$')
plt.savefig("plot.pdf", bbox = 'tight', transparent=True, dpi = 300)
# Out:
# NSIDE = 4096
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
